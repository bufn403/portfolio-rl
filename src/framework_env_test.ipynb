# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.callbacks import EvalCallback
import stable_baselines3
from portfolio_env_framework import *
import random
import torch
import torch.nn as nn
import numpy.typing as npt
import gymnasium as gym

# %% [markdown]
# ## Test

# %%
class BasicDataManager(AbstractDataManager):
    def get_obs_space(self) -> gym.spaces.Box:
        return gym.spaces.Box(low=-np.inf, high=np.inf, shape=(self.universe_size+1, 100+1), dtype=np.float32)

    def get_data(self) -> tuple[int, int]:
        # read SNP data
        df = pd.read_csv('crsp_snp100_2010_to_2024.csv', dtype='string')
    
        # convert datatypes
        df = df[['date', 'TICKER', 'PRC', 'VOL', 'ASKHI', 'BIDLO', 'FACPR']]
        df.date = pd.to_datetime(df.date)
        df.FACPR = df.FACPR.fillna('0.0')
        df.astype({
            'PRC': float,
            'VOL': float,
            'ASKHI': float,
            'BIDLO': float,
            'FACPR': float
        })
    
        # drop duplicates and nans
        df = df.drop_duplicates(subset=['date', 'TICKER'])
        df.dropna(inplace=True)
    
        # only include stocks that are present in all dates
        ticker_ok = df.TICKER.value_counts() == df.TICKER.value_counts().max()
        def is_max_val_count(ticker: str) -> bool:
          return ticker_ok[ticker]
        ok = df.apply(lambda row: is_max_val_count(row['TICKER']), axis=1)
        df = df[ok]
        df = df[(df.date.dt.year >= 2010) & (df.date.dt.year <= 2019)]
    
        # create stock array
        self.stock_df = df.pivot(index='date', columns='TICKER', values='PRC').astype(float)
        
        # adjust for stock splits
        facpr_df = df.pivot(index='date', columns='TICKER', values='FACPR').astype(float)
        self.stock_df = self.stock_df * (1+facpr_df).cumprod(axis=0)
        # assert np.all(self.stock_df.pct_change().iloc[1:, :] > -1), f"{(self.stock_df.pct_change().iloc[1:, :] <= -1).sum().sum()=}, {np.any(pd.isna(self.stock_df.pct_change().iloc[1:, :]))}"
        self.ret = np.log(self.stock_df.pct_change().iloc[1:, :] + 1)
    
        # get times and dickers
        self.times = df.date.unique()[1:]
        self.tickers = df.TICKER.unique()
    
        # read index data and compute volatilities
        idx_df = pd.read_csv('crsp_snpidx_2010_to_2024.csv', dtype={
          'DATE': 'string',
          'vwretd': float
        })
        idx_df.DATE = pd.to_datetime(idx_df.DATE)
        idx_df['vol_20'] = idx_df.vwretd.rolling(20).std()
        idx_df['vol_60'] = idx_df.vwretd.rolling(60).std()
        idx_df.set_index('DATE', inplace=True)
        self.vol_20 = idx_df.vol_20
        self.vol_60 = idx_df.vol_60
    
        # get vix data
        vix_df = pd.read_csv('crsp_vix_2010_to_2024.csv', dtype={
          'Date': 'string',
          'vix': float
        })
        vix_df.Date = pd.to_datetime(vix_df.Date)
        vix_df.set_index('Date', inplace=True)
        self.vix_df = vix_df.vix
        
        self.num_time_periods = len(self.times)-100-1
        self.universe_size = len(self.tickers)
        return self.num_time_periods, self.universe_size
    
    def get_state(self, t: int, w: npt.NDArray[np.float64], port_val: np.float64) -> npt.NDArray[np.float64]:
        # today is self.times[self.t+100]
        s = np.zeros((self.universe_size+1, 100+1))
        s[:, 0] = w
        # s[1:, :-1] = self.ret[self.t:self.t+100, :].T
        s[1:, :-1] = self.ret.loc[self.times[t:t+100], :].to_numpy().T # 100 past returns, up to yesterday
        s[-1, 1] = self.vol_20[self.times[t+100-1]] # yesterday's vol_20
        s[-1, 2] = self.vol_20[self.times[t+100-1]] / self.vol_60[self.times[t+100-1]] # yesterday's vol ratio
        s[-1, 3] = self.vix_df[self.times[t+100-1]] # yesterday's vix
        return s

    def get_prices(self, t: int) -> npt.NDArray[np.float64]:
        # today is self.times[self.t+100]
        return np.append(self.stock_df.loc[self.times[t+100], :].to_numpy().flatten(), 1.0)

# %%
class DifferentialSharpeRatioReward(AbstractRewardManager):
    def __init__(self, eta: float = 1/252):
        self.eta = eta
        self.initialize_reward()

    def initialize_reward(self):
        self.A, self.B = 0.0, 0.0

    def compute_reward(self, old_port_val: float, new_port_val: float) -> float:
        R = np.log(new_port_val / old_port_val)
        dA = R - self.A
        dB = R ** 2 - self.B
        if self.B - self.A ** 2 == 0:
            D = 0
        else:
            D = (self.B * dA - 0.5 * self.A * dB) / (self.B - self.A ** 2) ** (3 / 2)
        self.A += self.eta * dA
        self.B += self.eta * dB
        return D

# %%
# Parallel environments
vec_env = make_vec_env(PortfolioEnvWithTCost, n_envs=4, env_kwargs={
    'dm': BasicDataManager(),
    'rm': DifferentialSharpeRatioReward(),
    'cp': 0.10/365,
    'cs': 0.10/365
})

# Set seeds
random.seed(42)
np.random.seed(42)
vec_env.seed(42)
vec_env.action_space.seed(43)
torch.manual_seed(42)

model = PPO("MlpPolicy", vec_env, verbose=1)
model.learn(total_timesteps=100_000)
model.save("tcost_portfolio_rl_model_framework")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 2
#       1 # Parallel environments
# ----> 2 vec_env = make_vec_env(PortfolioEnvWithTCost, n_envs=4, env_kwargs={
#       3     'dm': BasicDataManager(),
#       4     'rm': DifferentialSharpeRatioReward(),
#       5     'cp': 0.10/365,
#       6     'cs': 0.10/365
#       7 })
#       9 # Set seeds
#      10 random.seed(42)
#
# File c:\Users\sumit\GitRepos\portfolio-rl\venv\Lib\site-packages\stable_baselines3\common\env_util.py:125, in make_vec_env(env_id, n_envs, seed, start_index, monitor_dir, wrapper_class, env_kwargs, vec_env_cls, vec_env_kwargs, monitor_kwargs, wrapper_kwargs)
#     121 if vec_env_cls is None:
#     122     # Default: use a DummyVecEnv
#     123     vec_env_cls = DummyVecEnv
# --> 125 vec_env = vec_env_cls([make_env(i + start_index) for i in range(n_envs)], **vec_env_kwargs)
#     126 # Prepare the seeds for the first reset
#     127 vec_env.seed(seed)
#
# File c:\Users\sumit\GitRepos\portfolio-rl\venv\Lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py:30, in DummyVecEnv.__init__(self, env_fns)
#      29 def __init__(self, env_fns: List[Callable[[], gym.Env]]):
# ---> 30     self.envs = [_patch_env(fn()) for fn in env_fns]
#      31     if len(set([id(env.unwrapped) for env in self.envs])) != len(self.envs):
#      32         raise ValueError(
#      33             "You tried to create multiple environments, but the function to create them returned the same instance "
#      34             "instead of creating different objects. "
#    (...)
#      39             "Please read https://github.com/DLR-RM/stable-baselines3/issues/1151 for more information."
#      40         )
#
# File c:\Users\sumit\GitRepos\portfolio-rl\venv\Lib\site-packages\stable_baselines3\common\env_util.py:98, in make_vec_env.<locals>.make_env.<locals>._init()
#      96         env = gym.make(env_id, **env_kwargs)
#      97 else:
# ---> 98     env = env_id(**env_kwargs)
#      99     # Patch to support gym 0.21/0.26 and gymnasium
#     100     env = _patch_env(env)
#
# File c:\Users\sumit\GitRepos\portfolio-rl\portfolio_env_framework.py:70, in PortfolioEnvWithTCost.__init__(self, dm, rm, w_lb, w_ub, cp, cs, logging)
#      67 self.logging = logging
#      69 # get data, set problem size
# ---> 70 self.num_time_periods, self.universe_size = self.dm.get_data()
#      72 # set spaces
#      73 assert w_lb <= w_ub
#
# Cell In[20], line 7, in BasicDataManager.get_data(self)
#       5 def get_data(self) -> tuple[int, int]:
#       6     # read SNP data
# ----> 7     df = pd.read_csv('crsp_snp100_2010_to_2024.csv', dtype='string')
#       9     # convert datatypes
#      10     df = df[['date', 'TICKER', 'PRC', 'VOL', 'ASKHI', 'BIDLO', 'FACPR']]
#
# File c:\Users\sumit\GitRepos\portfolio-rl\venv\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\sumit\GitRepos\portfolio-rl\venv\Lib\site-packages\pandas\io\parsers\readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File c:\Users\sumit\GitRepos\portfolio-rl\venv\Lib\site-packages\pandas\io\parsers\readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File c:\Users\sumit\GitRepos\portfolio-rl\venv\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File parsers.pyx:838, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File parsers.pyx:921, in pandas._libs.parsers.TextReader._read_rows()
#
# File parsers.pyx:1066, in pandas._libs.parsers.TextReader._convert_column_data()
#
# File parsers.pyx:1105, in pandas._libs.parsers.TextReader._convert_tokens()
#
# File parsers.pyx:1199, in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# File c:\Users\sumit\GitRepos\portfolio-rl\venv\Lib\site-packages\pandas\core\arrays\string_.py:186, in StringDtype.construct_array_type(self)
#     181         raise TypeError(f"Cannot construct a '{cls.__name__}' from '{string}'")
#     183 # https://github.com/pandas-dev/pandas/issues/36126
#     184 # error: Signature of "construct_array_type" incompatible with supertype
#     185 # "ExtensionDtype"
# --> 186 def construct_array_type(  # type: ignore[override]
#     187     self,
#     188 ) -> type_t[BaseStringArray]:
#     189     """
#     190     Return the array type associated with this dtype.
#     191
#    (...)
#     194     type
#     195     """
#     196     from pandas.core.arrays.string_arrow import (
#     197         ArrowStringArray,
#     198         ArrowStringArrayNumpySemantics,
#     199     )
#
# KeyboardInterrupt:

# %%
class TestBasicDataManager(AbstractDataManager):
    def get_obs_space(self) -> gym.spaces.Box:
        return gym.spaces.Box(low=-np.inf, high=np.inf, shape=(self.universe_size+1, 100+1), dtype=np.float32)

    def get_data(self) -> tuple[int, int]:
        # read SNP data
        df = pd.read_csv('crsp_snp100_2010_to_2024.csv', dtype='string')
    
        # convert datatypes
        df = df[['date', 'TICKER', 'PRC', 'VOL', 'ASKHI', 'BIDLO', 'FACPR']]
        df.date = pd.to_datetime(df.date)
        df.FACPR = df.FACPR.fillna('0.0')
        df.astype({
            'PRC': float,
            'VOL': float,
            'ASKHI': float,
            'BIDLO': float,
            'FACPR': float
        })
    
        # drop duplicates and nans
        df = df.drop_duplicates(subset=['date', 'TICKER'])
        df.dropna(inplace=True)
    
        # only include stocks that are present in all dates
        ticker_ok = df.TICKER.value_counts() == df.TICKER.value_counts().max()
        def is_max_val_count(ticker: str) -> bool:
          return ticker_ok[ticker]
        ok = df.apply(lambda row: is_max_val_count(row['TICKER']), axis=1)
        df = df[ok]
        df = df[(df.date.dt.year >= 2020) & (df.date.dt.year <= 2024)]
    
        # create stock array
        self.stock_df = df.pivot(index='date', columns='TICKER', values='PRC').astype(float)
        
        # adjust for stock splits
        facpr_df = df.pivot(index='date', columns='TICKER', values='FACPR').astype(float)
        self.stock_df = self.stock_df * (1+facpr_df).cumprod(axis=0)
        # assert np.all(self.stock_df.pct_change().iloc[1:, :] > -1), f"{(self.stock_df.pct_change().iloc[1:, :] <= -1).sum().sum()=}, {np.any(pd.isna(self.stock_df.pct_change().iloc[1:, :]))}"
        self.ret = np.log(self.stock_df.pct_change().iloc[1:, :] + 1)
    
        # get times and dickers
        self.times = df.date.unique()[1:]
        self.tickers = df.TICKER.unique()
    
        # read index data and compute volatilities
        idx_df = pd.read_csv('crsp_snpidx_2010_to_2024.csv', dtype={
          'DATE': 'string',
          'vwretd': float
        })
        idx_df.DATE = pd.to_datetime(idx_df.DATE)
        idx_df['vol_20'] = idx_df.vwretd.rolling(20).std()
        idx_df['vol_60'] = idx_df.vwretd.rolling(60).std()
        idx_df.set_index('DATE', inplace=True)
        self.idx_df = idx_df
        self.vol_20 = idx_df.vol_20
        self.vol_60 = idx_df.vol_60
    
        # get vix data
        vix_df = pd.read_csv('crsp_vix_2010_to_2024.csv', dtype={
          'Date': 'string',
          'vix': float
        })
        vix_df.Date = pd.to_datetime(vix_df.Date)
        vix_df.set_index('Date', inplace=True)
        self.vix_df = vix_df.vix
        
        self.num_time_periods = len(self.times)-100-1
        self.universe_size = len(self.tickers)
        return self.num_time_periods, self.universe_size
    
    def get_state(self, t: int, w: npt.NDArray[np.float64], port_val: np.float64) -> npt.NDArray[np.float64]:
        # today is self.times[self.t+100]
        s = np.zeros((self.universe_size+1, 100+1))
        s[:, 0] = w
        # s[1:, :-1] = self.ret[self.t:self.t+100, :].T
        s[1:, :-1] = self.ret.loc[self.times[t:t+100], :].to_numpy().T # 100 past returns, up to yesterday
        s[-1, 1] = self.vol_20[self.times[t+100-1]] # yesterday's vol_20
        s[-1, 2] = self.vol_20[self.times[t+100-1]] / self.vol_60[self.times[t+100-1]] # yesterday's vol ratio
        s[-1, 3] = self.vix_df[self.times[t+100-1]] # yesterday's vix
        return s

    def get_prices(self, t: int) -> npt.NDArray[np.float64]:
        # today is self.times[self.t+100]
        return np.append(self.stock_df.loc[self.times[t+100], :].to_numpy().flatten(), 1.0)

# %%
env = PortfolioEnvWithTCost(dm=TestBasicDataManager(), rm=DifferentialSharpeRatioReward(), cp=0.10/365, cs=0.10/365)
obs, _ = env.reset()

port_val = [1.0]
snp_val = [1.0]
actions = []
ys = []
times_arr = [env.dm.times[env.t+100]]
mus = []

for i in range(900):
    action, _ = model.predict(obs, deterministic=True)
    actions.append(action)
    obs, rewards, terminated, truncated, info = env.step(action)
    ys.append(env.y)
    mus.append(env.mu)
    times_arr.append(env.dm.times[env.t+100])
    port_val.append(info['port_val'])
    snp_val.append(snp_val[-1] * (1 + env.dm.idx_df[env.dm.idx_df.index == env.dm.times[env.t+100]].vwretd.values[0]))
    if terminated:
        break

# %%
plt.plot(times_arr, np.array(port_val), label='RL Portfolio')
plt.plot(times_arr, np.array(snp_val), label='S&P')
# plt.yscale('log')
plt.legend()
plt.show()

# %%
min(mus), max(mus)
# Out:
# (0.9995167124420706, 0.9998240884067789)

# %%
plt.plot(times_arr, np.array(port_val) / np.array([1, *mus]).cumprod(), label='RL Portfolio')
plt.plot(times_arr, np.array(snp_val), label='S&P')
# plt.yscale('log')
plt.legend()
plt.show()

# %% [markdown]
# ## Model Softmax

# %%
# Parallel environments
vec_env = make_vec_env(PortfolioEnvWithTCost, n_envs=4, env_kwargs={
    'dm': BasicDataManager(),
    'rm': DifferentialSharpeRatioReward(),
    'cp': 0.10/365,
    'cs': 0.10/365
})

# Set seeds
random.seed(42)
np.random.seed(42)
vec_env.seed(42)
vec_env.action_space.seed(43)
torch.manual_seed(42)

class SoftmaxActivation(nn.Module):
  def __init__(self):
    super().__init__()
    self.activation = nn.Softmax(dim=1)
  
  def forward(self, x):
    return self.activation(x)

model = PPO("MlpPolicy", vec_env, verbose=1, policy_kwargs=dict(activation_fn=SoftmaxActivation))
model.learn(total_timesteps=100_000)
model.save("tcost_portfolio_rl_model_framework_softmax")
# Out:
# Using cuda device
# -----------------------------
# | time/              |      |
# |    fps             | 465  |
# |    iterations      | 1    |
# |    time_elapsed    | 17   |
# |    total_timesteps | 8192 |
# -----------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.41e+03    |
# |    ep_rew_mean          | 6.54e+03    |
# | time/                   |             |
# |    fps                  | 381         |
# |    iterations           | 2           |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.011069694 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -121        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.34        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00933    |
# |    std                  | 0.999       |
# |    value_loss           | 1.57e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.41e+03    |
# |    ep_rew_mean          | 7.63e+03    |
# | time/                   |             |
# |    fps                  | 365         |
# |    iterations           | 3           |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.010288399 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -121        |
# |    explained_variance   | 1.79e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.94        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00835    |
# |    std                  | 0.999       |
# |    value_loss           | 2.8e+05     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.41e+03     |
# |    ep_rew_mean          | 7.78e+03     |
# | time/                   |              |
# |    fps                  | 355          |
# |    iterations           | 4            |
# |    time_elapsed         | 92           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0104511725 |
# |    clip_fraction        | 0.116        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -120         |
# |    explained_variance   | 1.23e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.6          |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00778     |
# |    std                  | 0.998        |
# |    value_loss           | 2.41e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.41e+03    |
# |    ep_rew_mean          | 7.64e+03    |
# | time/                   |             |
# |    fps                  | 351         |
# |    iterations           | 5           |
# |    time_elapsed         | 116         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.010494694 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -120        |
# |    explained_variance   | 5.06e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.98        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00864    |
# |    std                  | 0.997       |
# |    value_loss           | 1.93e+05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.41e+03   |
# |    ep_rew_mean          | 7.64e+03   |
# | time/                   |            |
# |    fps                  | 343        |
# |    iterations           | 6          |
# |    time_elapsed         | 142        |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.01100236 |
# |    clip_fraction        | 0.125      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -120       |
# |    explained_variance   | 8e-05      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.3        |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.00952   |
# |    std                  | 0.996      |
# |    value_loss           | 2.13e+05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.41e+03    |
# |    ep_rew_mean          | 7.64e+03    |
# | time/                   |             |
# |    fps                  | 343         |
# |    iterations           | 7           |
# |    time_elapsed         | 166         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.010676762 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -120        |
# |    explained_variance   | 0.000115    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.2         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.009      |
# |    std                  | 0.996       |
# |    value_loss           | 2.63e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.41e+03    |
# |    ep_rew_mean          | 7.77e+03    |
# | time/                   |             |
# |    fps                  | 343         |
# |    iterations           | 8           |
# |    time_elapsed         | 190         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.010779085 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -120        |
# |    explained_variance   | 0.605       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.865       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00958    |
# |    std                  | 0.995       |
# |    value_loss           | 2.63        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.41e+03    |
# |    ep_rew_mean          | 7.64e+03    |
# | time/                   |             |
# |    fps                  | 342         |
# |    iterations           | 9           |
# |    time_elapsed         | 215         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.012473894 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -120        |
# |    explained_variance   | 0.000216    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.718       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0111     |
# |    std                  | 0.995       |
# |    value_loss           | 1.72e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.41e+03    |
# |    ep_rew_mean          | 7.51e+03    |
# | time/                   |             |
# |    fps                  | 342         |
# |    iterations           | 10          |
# |    time_elapsed         | 239         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.011855743 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -120        |
# |    explained_variance   | 0.00026     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.3         |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00972    |
# |    std                  | 0.996       |
# |    value_loss           | 1.61e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.41e+03    |
# |    ep_rew_mean          | 7.65e+03    |
# | time/                   |             |
# |    fps                  | 341         |
# |    iterations           | 11          |
# |    time_elapsed         | 263         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.011186006 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -120        |
# |    explained_variance   | 0.000204    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.16        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00665    |
# |    std                  | 0.995       |
# |    value_loss           | 2.83e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.41e+03    |
# |    ep_rew_mean          | 7.71e+03    |
# | time/                   |             |
# |    fps                  | 339         |
# |    iterations           | 12          |
# |    time_elapsed         | 289         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.010800518 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -120        |
# |    explained_variance   | 0.00023     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.15        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00721    |
# |    std                  | 0.997       |
# |    value_loss           | 2.51e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.41e+03    |
# |    ep_rew_mean          | 7.58e+03    |
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 13          |
# |    time_elapsed         | 318         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.012602904 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -120        |
# |    explained_variance   | 0.000344    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.01        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0105     |
# |    std                  | 0.995       |
# |    value_loss           | 1.42e+05    |
# -----------------------------------------

# %%
env = PortfolioEnvWithTCost(dm=TestBasicDataManager(), rm=DifferentialSharpeRatioReward(), cp=0.10/365, cs=0.10/365)
obs, _ = env.reset()

port_val = [1.0]
snp_val = [1.0]
actions = []
ys = []
times_arr = [env.dm.times[env.t+100]]
mus = []

for i in range(900):
    action, _ = model.predict(obs, deterministic=True)
    actions.append(action)
    obs, rewards, terminated, truncated, info = env.step(action)
    ys.append(env.y)
    mus.append(env.mu)
    times_arr.append(env.dm.times[env.t+100])
    port_val.append(info['port_val'])
    snp_val.append(snp_val[-1] * (1 + env.dm.idx_df[env.dm.idx_df.index == env.dm.times[env.t+100]].vwretd.values[0]))
    if terminated:
        break

# %%
plt.plot(times_arr, np.array(port_val), label='RL Portfolio')
plt.plot(times_arr, np.array(snp_val), label='S&P')
# plt.yscale('log')
plt.legend()
plt.show()

# %% [markdown]
# ## Training Curves

# %%
# Parallel environments
import stable_baselines3.common
import stable_baselines3.common.logger


vec_env = make_vec_env(PortfolioEnvWithTCost, n_envs=4, env_kwargs={
    'dm': BasicDataManager(),
    'rm': DifferentialSharpeRatioReward(),
    'cp': 0.10/365,
    'cs': 0.10/365
})
eval_env = make_vec_env(PortfolioEnvWithTCost, n_envs=4, env_kwargs={
  'dm': TestBasicDataManager(),
  'rm': DifferentialSharpeRatioReward(),
  'cp': 0.10/365,
  'cs': 0.10/365
})

# Set seeds
random.seed(42)
np.random.seed(42)
vec_env.seed(42)
vec_env.action_space.seed(43)
eval_env.seed(42)
eval_env.action_space.seed(43)
torch.manual_seed(42)

eval_callback = EvalCallback(eval_env, log_path="./logs", eval_freq=10_000)

class SoftmaxActivation(nn.Module):
  def __init__(self):
    super().__init__()
    self.activation = nn.Softmax(dim=1)
  
  def forward(self, x):
    return self.activation(x)

model = PPO("MlpPolicy", vec_env, verbose=1, policy_kwargs=dict(activation_fn=SoftmaxActivation))
model.set_logger(stable_baselines3.common.logger.configure('./logs', ['csv', 'stdout']))
model.learn(total_timesteps=50_000, callback=eval_callback)
model.save("tcost_portfolio_rl_model_framework_softmax")
# Out:
# Using cuda device
# Logging to ./logs
# -----------------------------
# | time/              |      |
# |    fps             | 376  |
# |    iterations      | 1    |
# |    time_elapsed    | 21   |
# |    total_timesteps | 8192 |
# -----------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.41e+03    |
# |    ep_rew_mean          | 6.54e+03    |
# | time/                   |             |
# |    fps                  | 290         |
# |    iterations           | 2           |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.011069694 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -121        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.34        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00933    |
# |    std                  | 0.999       |
# |    value_loss           | 1.57e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.41e+03    |
# |    ep_rew_mean          | 7.63e+03    |
# | time/                   |             |
# |    fps                  | 262         |
# |    iterations           | 3           |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.010288399 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -121        |
# |    explained_variance   | 1.79e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.94        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00835    |
# |    std                  | 0.999       |
# |    value_loss           | 2.8e+05     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.41e+03     |
# |    ep_rew_mean          | 7.78e+03     |
# | time/                   |              |
# |    fps                  | 256          |
# |    iterations           | 4            |
# |    time_elapsed         | 127          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0104511725 |
# |    clip_fraction        | 0.116        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -120         |
# |    explained_variance   | 1.23e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.6          |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00778     |
# |    std                  | 0.998        |
# |    value_loss           | 2.41e+05     |
# ------------------------------------------
# Eval num_timesteps=40000, episode_reward=-21.13 +/- 64.22
# Episode length: 904.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 904         |
# |    mean_reward          | -21.1       |
# | time/                   |             |
# |    total_timesteps      | 40000       |
# | train/                  |             |
# |    approx_kl            | 0.010494694 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -120        |
# |    explained_variance   | 5.06e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.98        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00864    |
# |    std                  | 0.997       |
# |    value_loss           | 1.93e+05    |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.41e+03 |
# |    ep_rew_mean     | 7.64e+03 |
# | time/              |          |
# |    fps             | 228      |
# |    iterations      | 5        |
# |    time_elapsed    | 179      |
# |    total_timesteps | 40960    |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.41e+03   |
# |    ep_rew_mean          | 7.64e+03   |
# | time/                   |            |
# |    fps                  | 229        |
# |    iterations           | 6          |
# |    time_elapsed         | 214        |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.01100236 |
# |    clip_fraction        | 0.125      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -120       |
# |    explained_variance   | 8e-05      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.3        |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.00952   |
# |    std                  | 0.996      |
# |    value_loss           | 2.13e+05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.41e+03    |
# |    ep_rew_mean          | 7.64e+03    |
# | time/                   |             |
# |    fps                  | 231         |
# |    iterations           | 7           |
# |    time_elapsed         | 247         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.010676762 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -120        |
# |    explained_variance   | 0.000115    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.2         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.009      |
# |    std                  | 0.996       |
# |    value_loss           | 2.63e+05    |
# -----------------------------------------

# %%
progress = pd.read_csv('./logs/progress.csv')

# %%
progress['eval/mean_reward']
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4   -21.127969
# 5          NaN
# 6          NaN
# 7          NaN
# Name: eval/mean_reward, dtype: float64

# %%
progress.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   time/time_elapsed           7 non-null      float64
#  1   time/total_timesteps        8 non-null      int64
#  2   time/fps                    7 non-null      float64
#  3   time/iterations             7 non-null      float64
#  4   train/value_loss            6 non-null      float64
#  5   train/entropy_loss          6 non-null      float64
#  6   train/loss                  6 non-null      float64
#  7   train/policy_gradient_loss  6 non-null      float64
#  8   train/learning_rate         6 non-null      float64
#  9   train/explained_variance    6 non-null      float64
#  10  train/approx_kl             6 non-null      float64
#  11  train/clip_fraction         6 non-null      float64
#  12  rollout/ep_len_mean         6 non-null      float64
#  13  train/std                   6 non-null      float64
#  14  train/clip_range            6 non-null      float64
#  15  rollout/ep_rew_mean         6 non-null      float64
#  16  train/n_updates             6 non-null      float64
#  17  eval/mean_ep_length         1 non-null      float64
#  18  eval/mean_reward            1 non-null      float64
# dtypes: float64(18), int64(1)
# memory usage: 1.3 KB

# %%
plt.plot(progress['time/total_timesteps'], progress['eval/mean_reward'])
plt.show()

# %% [markdown]
# ## More Eval

# %%
# Parallel environments
import stable_baselines3.common
import stable_baselines3.common.logger


train_env = make_vec_env(PortfolioEnvWithTCost, n_envs=4, env_kwargs={
    'dm': BasicDataManager(),
    'rm': DifferentialSharpeRatioReward(),
    'cp': 0.10/365,
    'cs': 0.10/365
})
# eval_env = make_vec_env(PortfolioEnvWithTCost, n_envs=4, env_kwargs={
#   'dm': TestBasicDataManager(),
#   'rm': DifferentialSharpeRatioReward(),
#   'cp': 0.10/365,
#   'cs': 0.10/365
# })
eval_env = PortfolioEnvWithTCost(dm=TestBasicDataManager(), rm=DifferentialSharpeRatioReward(), cp=0.10/365, cs=0.10/365)

# Set seeds
random.seed(42)
np.random.seed(42)
train_env.seed(42)
train_env.action_space.seed(43)
# eval_env.seed(42)
# eval_env.action_space.seed(43)
torch.manual_seed(42)

class SoftmaxActivation(nn.Module):
  def __init__(self):
    super().__init__()
    self.activation = nn.Softmax(dim=1)
  
  def forward(self, x):
    return self.activation(x)
model = PPO("MlpPolicy", train_env, verbose=1, policy_kwargs=dict(activation_fn=SoftmaxActivation))
# Out:
# Using cuda device

# %%
log = []

for iteration in range(100):
    # learn
    print(f"Iteration {iteration}")
    if iteration == 0:
        model.learn(8000)
    else:
        model.learn(8000, reset_num_timesteps=False)

    # initialize
    obs, _ = eval_env.reset()
    port_val = [1.0]
    snp_val = [1.0]
    actions = []
    ys = []
    times_arr = [eval_env.dm.times[eval_env.t+100]]
    mus = []

    # run eval
    for i in range(900):
        action, _ = model.predict(obs, deterministic=True)
        actions.append(action)
        obs, rewards, terminated, truncated, info = eval_env.step(action)
        ys.append(eval_env.y)
        mus.append(eval_env.mu)
        times_arr.append(eval_env.dm.times[eval_env.t+100])
        port_val.append(info['port_val'])
        snp_val.append(snp_val[-1] * (1 + eval_env.dm.idx_df[eval_env.dm.idx_df.index == eval_env.dm.times[eval_env.t+100]].vwretd.values[0]))
        if terminated:
            break

    # log everything
    log.append({
        'port_val': port_val,
        'snp_val': snp_val,
        'actions': actions,
        'times_arr': times_arr
    })
# Out:
# Iteration 0
# -----------------------------
# | time/              |      |
# |    fps             | 444  |
# |    iterations      | 1    |
# |    time_elapsed    | 18   |
# |    total_timesteps | 8192 |
# -----------------------------
# Iteration 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.41e+03 |
# |    ep_rew_mean     | 6.54e+03 |
# | time/              |          |
# |    fps             | 477      |
# |    iterations      | 1        |
# |    time_elapsed    | 17       |
# |    total_timesteps | 16384    |
# ---------------------------------
# Iteration 2
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.41e+03 |
# |    ep_rew_mean     | 7.63e+03 |
# | time/              |          |
# |    fps             | 422      |
# |    iterations      | 1        |
# |    time_elapsed    | 19       |
# |    total_timesteps | 24576    |
# ---------------------------------
# Iteration 3
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.41e+03 |
# |    ep_rew_mean     | 7.78e+03 |
# | time/              |          |
# |    fps             | 405      |
# |    iterations      | 1        |
# |    time_elapsed    | 20       |
# |    total_timesteps | 32768    |
# ---------------------------------
# Iteration 4
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.41e+03 |
# |    ep_rew_mean     | 7.64e+03 |
# | time/              |          |
# |    fps             | 463      |
# |    iterations      | 1        |
# |    time_elapsed    | 17       |
# |    total_timesteps | 40960    |
# ---------------------------------
# Iteration 5
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.41e+03 |
# |    ep_rew_mean     | 7.64e+03 |
# | time/              |          |
# |    fps             | 461      |
# |    iterations      | 1        |
# |    time_elapsed    | 17       |
# |    total_timesteps | 49152    |
# ---------------------------------
# Iteration 6
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.41e+03 |
# |    ep_rew_mean     | 7.64e+03 |
# | time/              |          |
# |    fps             | 470      |
# |    iterations      | 1        |
# |    time_elapsed    | 17       |
# |    total_timesteps | 57344    |
# ---------------------------------
# Iteration 7
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.41e+03 |
# |    ep_rew_mean     | 7.77e+03 |
# | time/              |          |
# |    fps             | 431      |
# |    iterations      | 1        |
# |    time_elapsed    | 18       |
# |    total_timesteps | 65536    |
# ---------------------------------
# Iteration 8
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.41e+03 |
# |    ep_rew_mean     | 7.64e+03 |
# | time/              |          |
# |    fps             | 477      |
# |    iterations      | 1        |
# |    time_elapsed    | 17       |
# |    total_timesteps | 73728    |
# ---------------------------------
# Iteration 9
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.41e+03 |
# |    ep_rew_mean     | 7.51e+03 |
# | time/              |          |
# |    fps             | 473      |
# |    iterations      | 1        |
# |    time_elapsed    | 17       |
# |    total_timesteps | 81920    |
# ---------------------------------
# Iteration 10
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.41e+03 |
# |    ep_rew_mean     | 7.65e+03 |
# | time/              |          |
# |    fps             | 472      |
# |    iterations      | 1        |
# |    time_elapsed    | 17       |
# |    total_timesteps | 90112    |
# ---------------------------------
# Iteration 11
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.41e+03 |
# |    ep_rew_mean     | 7.71e+03 |
# | time/              |          |
# |    fps             | 465      |
# |    iterations      | 1        |
# |    time_elapsed    | 17       |
# |    total_timesteps | 98304    |
# ---------------------------------
# Iteration 12
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.41e+03 |
# |    ep_rew_mean     | 7.58e+03 |
# | time/              |          |
# |    fps             | 479      |
# |    iterations      | 1        |
# |    time_elapsed    | 17       |
# |    total_timesteps | 106496   |
# ---------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 9
#       7     model.learn(8000)
#       8 else:
# ----> 9     model.learn(8000, reset_num_timesteps=False)
#      11 # initialize
#      12 obs, _ = eval_env.reset()
#
# File c:\Users\sumit\GitRepos\portfolio-rl\venv\Lib\site-packages\stable_baselines3\ppo\ppo.py:315, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     306 def learn(
#     307     self: SelfPPO,
#     308     total_timesteps: int,
#    (...)
#     313     progress_bar: bool = False,
#     314 ) -> SelfPPO:
# --> 315     return super().learn(
#     316         total_timesteps=total_timesteps,
#     317         callback=callback,
#     318         log_interval=log_interval,
#     319         tb_log_name=tb_log_name,
#     320         reset_num_timesteps=reset_num_timesteps,
#     321         progress_bar=progress_bar,
#     322     )
#
# File c:\Users\sumit\GitRepos\portfolio-rl\venv\Lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:299, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     296         self.logger.record("time/total_timesteps", self.num_timesteps, exclude="tensorboard")
#     297         self.logger.dump(step=self.num_timesteps)
# --> 299     self.train()
#     301 callback.on_training_end()
#     303 return self
#
# File c:\Users\sumit\GitRepos\portfolio-rl\venv\Lib\site-packages\stable_baselines3\ppo\ppo.py:217, in PPO.train(self)
#     214 if self.use_sde:
#     215     self.policy.reset_noise(self.batch_size)
# --> 217 values, log_prob, entropy = self.policy.evaluate_actions(rollout_data.observations, actions)
#     218 values = values.flatten()
#     219 # Normalize advantage
#
# File c:\Users\sumit\GitRepos\portfolio-rl\venv\Lib\site-packages\stable_baselines3\common\policies.py:737, in ActorCriticPolicy.evaluate_actions(self, obs, actions)
#     735     latent_pi = self.mlp_extractor.forward_actor(pi_features)
#     736     latent_vf = self.mlp_extractor.forward_critic(vf_features)
# --> 737 distribution = self._get_action_dist_from_latent(latent_pi)
#     738 log_prob = distribution.log_prob(actions)
#     739 values = self.value_net(latent_vf)
#
# File c:\Users\sumit\GitRepos\portfolio-rl\venv\Lib\site-packages\stable_baselines3\common\policies.py:694, in ActorCriticPolicy._get_action_dist_from_latent(self, latent_pi)
#     691 mean_actions = self.action_net(latent_pi)
#     693 if isinstance(self.action_dist, DiagGaussianDistribution):
# --> 694     return self.action_dist.proba_distribution(mean_actions, self.log_std)
#     695 elif isinstance(self.action_dist, CategoricalDistribution):
#     696     # Here mean_actions are the logits before the softmax
#     697     return self.action_dist.proba_distribution(action_logits=mean_actions)
#
# File c:\Users\sumit\GitRepos\portfolio-rl\venv\Lib\site-packages\stable_baselines3\common\distributions.py:164, in DiagGaussianDistribution.proba_distribution(self, mean_actions, log_std)
#     156 """
#     157 Create the distribution given its parameters (mean, std)
#     158
#    (...)
#     161 :return:
#     162 """
#     163 action_std = th.ones_like(mean_actions) * log_std.exp()
# --> 164 self.distribution = Normal(mean_actions, action_std)
#     165 return self
#
# File c:\Users\sumit\GitRepos\portfolio-rl\venv\Lib\site-packages\torch\distributions\normal.py:56, in Normal.__init__(self, loc, scale, validate_args)
#      54 else:
#      55     batch_shape = self.loc.size()
# ---> 56 super().__init__(batch_shape, validate_args=validate_args)
#
# File c:\Users\sumit\GitRepos\portfolio-rl\venv\Lib\site-packages\torch\distributions\distribution.py:67, in Distribution.__init__(self, batch_shape, event_shape, validate_args)
#      65         value = getattr(self, param)
#      66         valid = constraint.check(value)
# ---> 67         if not valid.all():
#      68             raise ValueError(
#      69                 f"Expected parameter {param} "
#      70                 f"({type(value).__name__} of shape {tuple(value.shape)}) "
#    (...)
#      73                 f"but found invalid values:\n{value}"
#      74             )
#      75 super().__init__()
#
# KeyboardInterrupt:

# %%
list(log[0].keys())
# Out:
# ['port_val', 'snp_val', 'actions', 'times_arr']

# %%
fig, axs = plt.subplots(1, 2)
axs[0].plot(list(map(lambda d: d['port_val'][-1], log)))
axs[0].set_title('Final Portfolio Value')
axs[1].plot(list(map(lambda d: np.mean(np.array(d['port_val'][1:]) - np.array(d['port_val'][:-1])) / np.std(np.array(d['port_val'][1:]) - np.array(d['port_val'][:-1])), log)))
axs[1].set_title('Sharpe Ratio')
plt.show()
