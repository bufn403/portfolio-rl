# %% [markdown]
# TODO:
# * get rid of [-1, 2], make all final action positive
# * in policy, do softmax, scale to [-1, 1], then in env scale back (already done)
# * add profit rewards back in; hp tune?
# * get rid of features=0 requirement (linear model?)
#
# investigate size (should be 17, not 17*85 ??)
#
# gives /0 error for some reason?
#
# also how is this not literally equiv to impossible??

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.callbacks import EvalCallback
import stable_baselines3
from portfolio_env_framework import *
import random
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy.typing as npt
import gymnasium as gym

# %%
class TrainDataManager(AbstractDataManager):
    def get_obs_space(self) -> gym.spaces.Box:
        return gym.spaces.Dict({
            'data': gym.spaces.Box(low=-np.inf, high=np.inf, shape=(2, self.universe_size+1, 3), dtype=np.float32),
            'weights': gym.spaces.Box(low=0, high=1, shape=(self.universe_size+1,), dtype=np.float32)
        })

    def get_data(self) -> tuple[int, int]:
        # read SNP data
        df = pd.read_csv('crsp_snp100_2010_to_2024.csv', dtype='string')
    
        # convert datatypes
        df = df[['date', 'TICKER', 'PRC', 'VOL', 'ASKHI', 'BIDLO', 'FACPR']]
        df.date = pd.to_datetime(df.date)
        df.FACPR = df.FACPR.fillna('0.0')
        df.astype({
            'PRC': float,
            'VOL': float,
            'ASKHI': float,
            'BIDLO': float,
            'FACPR': float
        })
    
        # drop duplicates and nans
        df = df.drop_duplicates(subset=['date', 'TICKER'])
        df.dropna(inplace=True)
    
        # only include stocks that are present in all dates
        lst = ['AAPL', 'AMD', 'AMZN', 'IBM',]
        ticker_ok = df.TICKER.value_counts() == df.TICKER.value_counts().max()
        def is_max_val_count(ticker: str) -> bool:
          return ticker_ok[ticker] and (ticker in lst)
        ok = df.apply(lambda row: is_max_val_count(row['TICKER']), axis=1)
        df = df[ok]
        df = df[(df.date.dt.year >= 2010) & (df.date.dt.year <= 2019)]
    
        # create stock array
        self.stock_df = df.pivot(index='date', columns='TICKER', values='PRC').astype(float)
        self.high_df = df.pivot(index='date', columns='TICKER', values='ASKHI').astype(float)
        self.low_df = df.pivot(index='date', columns='TICKER', values='BIDLO').astype(float)
        
        # adjust for stock splits
        facpr_df = df.pivot(index='date', columns='TICKER', values='FACPR').astype(float)
        self.stock_df = self.stock_df * (1+facpr_df).cumprod(axis=0)
        self.high_df = self.high_df * (1+facpr_df).cumprod(axis=0)
        self.low_df = self.low_df * (1+facpr_df).cumprod(axis=0)
        self.ret = np.log(self.stock_df.pct_change().iloc[1:, :] + 1)
    
        # get times and dickers
        self.times = df.date.unique()[1:]
        self.tickers = df.TICKER.unique()
        
        self.num_time_periods = len(self.times)-15-1
        self.universe_size = len(self.tickers)
        print(f"{self.universe_size=}")
        return self.num_time_periods, self.universe_size
    
    def get_state(self, t: int, w: npt.NDArray[np.float64], port_val: np.float64) -> npt.NDArray[np.float64]:
        # today is self.times[self.t+15]
        s = np.zeros((2, self.universe_size+1, 3))

        # s[0, :-1, :] = self.stock_df.loc[self.times[t:t+3], :].to_numpy().T
        s[0, :, :] = np.linspace(0, 1, 5).repeat(3).reshape(5, 3)
        s[1, :-1, :] = self.high_df.loc[self.times[t:t+3], :].to_numpy().T
        s[1, :-1, :] = np.random.normal(2.6, 0.5, (4, 3))
        # s[2, :-1, :] = self.low_df.loc[self.times[t:t+3], :].to_numpy().T
        
        s[:, -1, :] = 1.0
        # print(f"{s.shape=}, {s=}")
        return {'data': s, 'weights': w}

    def get_prices(self, t: int) -> npt.NDArray[np.float64]:
        # today is self.times[self.t+3]
        return np.append(self.stock_df.loc[self.times[t+3], :].to_numpy().flatten(), 1.0)

# %%
class DifferentialSharpeRatioReward(AbstractRewardManager):
    def __init__(self, eta: float = 1/252):
        self.eta = eta
        self.initialize_reward()

    def initialize_reward(self):
        self.A, self.B = 0.0, 0.0

    def compute_reward(self, old_port_val: float, new_port_val: float) -> float:
        R = np.log(new_port_val / old_port_val)
        dA = R - self.A
        dB = R ** 2 - self.B
        if self.B - self.A ** 2 == 0:
            D = 0
        else:
            D = (self.B * dA - 0.5 * self.A * dB) / (self.B - self.A ** 2) ** (3 / 2)
        self.A += self.eta * dA
        self.B += self.eta * dB
        return D

# %%
class ProfitReward(AbstractRewardManager):
    def __init__(self):
        pass

    def initialize_reward(self):
        pass

    def compute_reward(self, old_port_val: float, new_port_val: float) -> float:
        return new_port_val - old_port_val

# %%
class TestDataManager(AbstractDataManager):
    def get_obs_space(self) -> gym.spaces.Box:
        return gym.spaces.Dict({
            'data': gym.spaces.Box(low=-np.inf, high=np.inf, shape=(3, self.universe_size+1, 15), dtype=np.float32),
            'weights': gym.spaces.Box(low=0, high=1, shape=(self.universe_size+1,), dtype=np.float32)
        })

    def get_data(self) -> tuple[int, int]:
        # read SNP data
        df = pd.read_csv('crsp_snp100_2010_to_2024.csv', dtype='string')
    
        # convert datatypes
        df = df[['date', 'TICKER', 'PRC', 'VOL', 'ASKHI', 'BIDLO', 'FACPR']]
        df.date = pd.to_datetime(df.date)
        df.FACPR = df.FACPR.fillna('0.0')
        df.astype({
            'PRC': float,
            'VOL': float,
            'ASKHI': float,
            'BIDLO': float,
            'FACPR': float
        })
    
        # drop duplicates and nans
        df = df.drop_duplicates(subset=['date', 'TICKER'])
        df.dropna(inplace=True)
    
        # only include stocks that are present in all dates
        ticker_ok = df.TICKER.value_counts() == df.TICKER.value_counts().max()
        def is_max_val_count(ticker: str) -> bool:
          return ticker_ok[ticker]
        ok = df.apply(lambda row: is_max_val_count(row['TICKER']), axis=1)
        df = df[ok]
        df = df[(df.date.dt.year >= 2020) & (df.date.dt.year <= 2024)]
    
        # create stock array
        self.stock_df = df.pivot(index='date', columns='TICKER', values='PRC').astype(float)
        self.high_df = df.pivot(index='date', columns='TICKER', values='ASKHI').astype(float)
        self.low_df = df.pivot(index='date', columns='TICKER', values='BIDLO').astype(float)
        
        # adjust for stock splits
        facpr_df = df.pivot(index='date', columns='TICKER', values='FACPR').astype(float)
        self.stock_df = self.stock_df * (1+facpr_df).cumprod(axis=0)
        self.high_df = self.high_df * (1+facpr_df).cumprod(axis=0)
        self.low_df = self.low_df * (1+facpr_df).cumprod(axis=0)
        # assert np.all(self.stock_df.pct_change().iloc[1:, :] > -1), f"{(self.stock_df.pct_change().iloc[1:, :] <= -1).sum().sum()=}, {np.any(pd.isna(self.stock_df.pct_change().iloc[1:, :]))}"
        self.ret = np.log(self.stock_df.pct_change().iloc[1:, :] + 1)
    
        # get times and dickers
        self.times = df.date.unique()[1:]
        self.tickers = df.TICKER.unique()
        
        self.num_time_periods = len(self.times)-15-1
        self.universe_size = len(self.tickers)

        # read index data and compute volatilities
        idx_df = pd.read_csv('crsp_snpidx_2010_to_2024.csv', dtype={
          'DATE': 'string',
          'vwretd': float
        })
        idx_df.DATE = pd.to_datetime(idx_df.DATE)
        idx_df['vol_20'] = idx_df.vwretd.rolling(20).std()
        idx_df['vol_60'] = idx_df.vwretd.rolling(60).std()
        idx_df.set_index('DATE', inplace=True)
        self.idx_df = idx_df

        return self.num_time_periods, self.universe_size
    
    def get_state(self, t: int, w: npt.NDArray[np.float64], port_val: np.float64) -> npt.NDArray[np.float64]:
        # today is self.times[self.t+15]
        s = np.zeros((3, self.universe_size+1, 15))

        # s[0, :-1, :] = self.stock_df.loc[self.times[t:t+15], :].to_numpy().T
        s[0, :, :] = np.linspace(0, 1, 85).repeat(15).reshape(85, 15)
        s[1, :-1, :] = self.high_df.loc[self.times[t:t+15], :].to_numpy().T
        s[2, :-1, :] = self.low_df.loc[self.times[t:t+15], :].to_numpy().T
        
        s[:, -1, :] = 1.0
        # print(f"{s.shape=}, {s=}")
        return {'data': s, 'weights': w}

    def get_prices(self, t: int) -> npt.NDArray[np.float64]:
        # today is self.times[self.t+15]
        return np.append(self.stock_df.loc[self.times[t+15], :].to_numpy().flatten(), 1.0)

# %%
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor

class Custom_EIEE_CNN_Extractor(BaseFeaturesExtractor):
    def __init__(self, observation_space: gym.spaces.Dict, features_dim: int = 5*4):
        super(Custom_EIEE_CNN_Extractor, self).__init__(observation_space, features_dim)
        n_channels, self.universe_size_w_rfa, data_len = observation_space['data'].shape
        n_output_channels = 16
        # self.cnn = nn.Sequential(
        #     nn.Conv1d(n_channels, 4, kernel_size=(3,)),
        #     # nn.ReLU(),
        #     # nn.Conv1d(5, 7, kernel_size=(3,)),
        #     # nn.ReLU(),
        #     # nn.Conv1d(7, 9, kernel_size=(3,)),
        #     # nn.ReLU(),
        #     # nn.Conv1d(9, 11, kernel_size=(data_len-6,)),
        # ).cuda()
        # self.cnn = nn.Conv1d(n_channels, 2, (data_len,)).cuda()
        # self.v_cnn = torch.vmap(self.cnn, in_dims=2, out_dims=2)
        self.cnn = nn.Conv2d(n_channels, 4, (1, data_len)).cuda()

    def forward(self, observations: dict[str, torch.Tensor]) -> torch.Tensor:
        # print(f"{observations['data'].shape=}")
        x = self.cnn(observations['data'])
        return x.flatten(start_dim=1)
        # print(f"{observations['data'].shape=}")

        # x = observations['data'][:, :, :, 0]
        # print(f"{x.shape=}, {x=}")

        x = observations['data'][:, 0, :, 0]
        return x.flatten(start_dim=1)

        # print(f"{x.shape=}, {x.detach().cpu().numpy()=}")
        # print(f"{x[:, 0, :].detach().cpu().numpy()=}")
        w = observations['weights'][:, None, :]
        y = torch.cat((x.squeeze(-1), w), dim=1)
        # print(f"{y.detach().cpu().numpy()=}")
        # return y
        # return torch.ones_like(y).to(device=y.device, dtype=y.dtype)
        return y.flatten(start_dim=1)

# %%
# class Custom_EIEE_Network(nn.Module):
#     def __init__(self, observation_space: gym.spaces.Dict, input_features: int = 3, *args, **kwargs):
#         super(Custom_EIEE_Network, self).__init__(*args, **kwargs)
#         self.observation_space = observation_space
#         self.net = nn.Sequential(
#             nn.Linear(input_features, 1)
#         )
#         self.vec_net = torch.vmap(torch.vmap(self.net))

#     def forward(self, features: torch.Tensor) -> tuple[torch.Tensor, torch.Tensor]:
#         x = self.vec_net(torch.transpose(features, 1, 2)).squeeze(-1)
#         print(f"{x=}")
#         x_hat = 2 * nn.functional.softmax(5 * x, dim=1) - 1
#         return x_hat

# %%
# from stable_baselines3.td3.policies import Actor
# from stable_baselines3.common.policies import BaseModel
# from stable_baselines3.common.preprocessing import get_action_dim

# class CustomActor(Actor):
#     def __init__(self, observation_space: gym.spaces.Dict, *args, **kwargs):
#         super(CustomActor, self).__init__(observation_space, *args, **kwargs)
#         self.mu = Custom_EIEE_Network(observation_space)

# class DenseMlp(nn.Module):
#     def __init__(
#         self,
#         input_dim: int,
#         output_dim: int,
#         hidden_dim: int = 16,
#         n_layers: int = 2,
#         squash_output: bool = False,
#     ):
#         super(DenseMlp, self).__init__()
#         self.input_dim = input_dim
#         self.output_dim = output_dim
#         self.squash_output = squash_output
#         self.layer_1 = nn.Linear(input_dim, hidden_dim)
#         self.layer_2 = nn.Linear(hidden_dim + input_dim, hidden_dim)
#         if output_dim > 0:
#             self.output_layer = nn.Linear(hidden_dim + input_dim, output_dim)
#         self.output_activation = nn.Tanh()

#     def forward(self, input_tensor: torch.Tensor) -> torch.Tensor:
#         out_1 = F.relu(self.layer_1(input_tensor))
#         input_2 = torch.cat([out_1, input_tensor], dim=1)
#         out_2 = F.relu(self.layer_2(input_2))

#         if self.output_dim < 0:
#             return out_2

#         input_3 = torch.cat([out_2, input_tensor], dim=1)
#         out_3 = self.output_layer(input_3)

#         if self.squash_output:
#             out_3 = self.output_activation(out_3)
#         return out_3

# class DenseContinuousCritic(BaseModel):
#     def __init__(
#         self,
#         observation_space: gym.spaces.Space,
#         action_space: gym.spaces.Space,
#         net_arch: list[int],
#         features_extractor: nn.Module,
#         features_dim: int,
#         activation_fn: type[nn.Module] = nn.ReLU,
#         normalize_images: bool = True,
#         n_critics: int = 2,
#         share_features_extractor: bool = True,
#     ):
#         super().__init__(
#             observation_space,
#             action_space,
#             features_extractor=features_extractor,
#             normalize_images=normalize_images,
#         )

#         action_dim = get_action_dim(self.action_space)

#         self.share_features_extractor = share_features_extractor
#         self.n_critics = n_critics
#         self.q_networks = []
#         features_dim = 4 * 5 # TODO: bad idea
#         for idx in range(n_critics):
#             q_net = DenseMlp(features_dim, 1)
#             self.add_module(f"qf{idx}", q_net)
#             self.q_networks.append(q_net)

#     def forward(self, obs: torch.Tensor, actions: torch.Tensor) -> tuple[torch.Tensor, ...]:
#         # Learn the features extractor using the policy loss only
#         # when the features_extractor is shared with the actor
#         with torch.set_grad_enabled(not self.share_features_extractor):
#             features = self.extract_features(obs, self.features_extractor)
#         qvalue_input = torch.cat([features, actions[:, None, :]], dim=1).flatten(start_dim=1)
#         return tuple(q_net(qvalue_input) for q_net in self.q_networks)

#     def q1_forward(self, obs: torch.Tensor, actions: torch.Tensor) -> torch.Tensor:
#         """
#         Only predict the Q-value using the first network.
#         This allows to reduce computation when all the estimates are not needed
#         (e.g. when updating the policy in TD3).
#         """
#         with torch.no_grad():
#             features = self.extract_features(obs, self.features_extractor)
#         # print(f"features mean={features.mean().detach().cpu().numpy()}, std={features.std().detach().cpu().numpy()}")
#         # print(f"actions min={actions.detach().cpu().min()}, max={actions.detach().cpu().max()}, median={actions.median().detach().cpu().numpy()}, mean={actions.mean().detach().cpu().numpy()}, std={actions.std().detach().cpu().numpy()}")       
#         q1 = self.q_networks[0](torch.cat([features, actions[:, None, :]], dim=1).flatten(start_dim=1))
#         # print(f"q1 mean={q1.mean().detach().cpu().numpy()}, std={q1.std().detach().cpu().numpy()}")
#         return q1

# %%
# from typing import Optional
# from stable_baselines3.td3.policies import TD3Policy

# class CustomTD3Policy(TD3Policy):
#     def __init__(self, observation_space: gym.spaces.Dict, *args, **kwargs):
#         super(CustomTD3Policy, self).__init__(observation_space, *args, **kwargs)
#         self.observation_space = observation_space

#     def make_actor(self, features_extractor: Optional[BaseFeaturesExtractor] = None) -> CustomActor:
#         actor_kwargs = self._update_features_extractor(self.actor_kwargs, features_extractor)
#         return CustomActor(**actor_kwargs).to(self.device)

#     def make_critic(self, features_extractor: Optional[BaseFeaturesExtractor] = None) -> DenseContinuousCritic:
#         critic_kwargs = self._update_features_extractor(self.critic_kwargs, features_extractor)
#         return DenseContinuousCritic(**critic_kwargs).to(self.device)

# %%
# Parallel environments
from stable_baselines3 import DDPG, SAC
from stable_baselines3.common.noise import NormalActionNoise

train_env = PortfolioEnvWithTCost(dm=TrainDataManager(), rm=ProfitReward(), cp=0.01, cs=0.01)

# Set seeds
random.seed(42)
np.random.seed(42)
# train_env.seed(42)
train_env.action_space.seed(43)
torch.manual_seed(42)

# model = DDPG(CustomTD3Policy, train_env, buffer_size=250, verbose=1, policy_kwargs={
#   'features_extractor_class': Custom_EIEE_CNN_Extractor,
#   'net_arch': [16, 16],
#   'optimizer_class': torch.optim.AdamW
# })
# }, action_noise=NormalActionNoise(mean=np.zeros((85,)), sigma=0.1),)
model = DDPG('MultiInputPolicy', train_env, buffer_size=10**7, verbose=1, policy_kwargs={
  'features_extractor_class': Custom_EIEE_CNN_Extractor,
  # 'net_arch': [50, 50],
}, action_noise=NormalActionNoise(mean=0, sigma=0.10*np.ones(5)))
# }, action_noise=NormalActionNoise(mean=np.zeros((85,)), sigma=0.1),)
model.learn(total_timesteps=10**10, log_interval=1)
# model.save("cnn_portoflio_policy")
# Out:
# self.universe_size=4
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | -1e+12   |
# | time/              |          |
# |    episodes        | 1        |
# |    fps             | 223      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 120      |
# | train/             |          |
# |    actor_loss      | 25.6     |
# |    critic_loss     | 9.71e+04 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 19       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -1e+12   |
# | time/              |          |
# |    episodes        | 2        |
# |    fps             | 147      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 198      |
# | train/             |          |
# |    actor_loss      | 3.24e+03 |
# |    critic_loss     | 7.91e+06 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 97       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 69       |
# |    ep_rew_mean     | -1e+12   |
# | time/              |          |
# |    episodes        | 3        |
# |    fps             | 146      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 207      |
# | train/             |          |
# |    actor_loss      | 4.55e+03 |
# |    critic_loss     | 7.81e+21 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 106      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 55.2     |
# |    ep_rew_mean     | -1e+12   |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 143      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 221      |
# | train/             |          |
# |    actor_loss      | 8.34e+03 |
# |    critic_loss     | 7.81e+21 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 120      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 53.4     |
# |    ep_rew_mean     | -1e+12   |
# | time/              |          |
# |    episodes        | 5        |
# |    fps             | 138      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 267      |
# | train/             |          |
# |    actor_loss      | 4.27e+04 |
# |    critic_loss     | 1.95e+22 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 166      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 45.5     |
# |    ep_rew_mean     | -1e+12   |
# | time/              |          |
# |    episodes        | 6        |
# |    fps             | 138      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 273      |
# | train/             |          |
# |    actor_loss      | 5.09e+04 |
# |    critic_loss     | 2.34e+22 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 172      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 40       |
# |    ep_rew_mean     | -1e+12   |
# | time/              |          |
# |    episodes        | 7        |
# |    fps             | 137      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 280      |
# | train/             |          |
# |    actor_loss      | 6.27e+04 |
# |    critic_loss     | 1.17e+22 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 179      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 38       |
# |    ep_rew_mean     | -1e+12   |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 135      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 304      |
# | train/             |          |
# |    actor_loss      | 1.18e+05 |
# |    critic_loss     | 4.3e+22  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 203      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 35.3     |
# |    ep_rew_mean     | -1e+12   |
# | time/              |          |
# |    episodes        | 9        |
# |    fps             | 134      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 318      |
# | train/             |          |
# |    actor_loss      | 1.6e+05  |
# |    critic_loss     | 3.52e+22 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 217      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 34.4     |
# |    ep_rew_mean     | -1e+12   |
# | time/              |          |
# |    episodes        | 10       |
# |    fps             | 133      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 344      |
# | train/             |          |
# |    actor_loss      | 2.82e+05 |
# |    critic_loss     | 3.91e+22 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 243      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 31.4     |
# |    ep_rew_mean     | -1e+12   |
# | time/              |          |
# |    episodes        | 11       |
# |    fps             | 132      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 345      |
# | train/             |          |
# |    actor_loss      | 2.87e+05 |
# |    critic_loss     | 5.08e+22 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 244      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29.5     |
# |    ep_rew_mean     | -1e+12   |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 132      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 354      |
# | train/             |          |
# |    actor_loss      | 3.45e+05 |
# |    critic_loss     | 1.95e+22 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 253      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 28.2     |
# |    ep_rew_mean     | -1e+12   |
# | time/              |          |
# |    episodes        | 13       |
# |    fps             | 131      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 367      |
# | train/             |          |
# |    actor_loss      | 4.39e+05 |
# |    critic_loss     | 3.12e+22 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 266      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 26.8     |
# |    ep_rew_mean     | -1e+12   |
# | time/              |          |
# |    episodes        | 14       |
# |    fps             | 131      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 375      |
# | train/             |          |
# |    actor_loss      | 5.06e+05 |
# |    critic_loss     | 1.95e+22 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 274      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 26.5     |
# |    ep_rew_mean     | -1e+12   |
# | time/              |          |
# |    episodes        | 15       |
# |    fps             | 130      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 397      |
# | train/             |          |
# |    actor_loss      | 7.22e+05 |
# |    critic_loss     | 4.3e+22  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 296      |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 181       |
# |    ep_rew_mean     | -9.38e+11 |
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 120       |
# |    time_elapsed    | 24        |
# |    total_timesteps | 2896      |
# | train/             |           |
# |    actor_loss      | 1.53e+09  |
# |    critic_loss     | 9.31e+16  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 2795      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 317       |
# |    ep_rew_mean     | -8.82e+11 |
# | time/              |           |
# |    episodes        | 17        |
# |    fps             | 121       |
# |    time_elapsed    | 44        |
# |    total_timesteps | 5395      |
# | train/             |           |
# |    actor_loss      | 7.55e+09  |
# |    critic_loss     | 6.01e+17  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 5294      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 439       |
# |    ep_rew_mean     | -8.33e+11 |
# | time/              |           |
# |    episodes        | 18        |
# |    fps             | 121       |
# |    time_elapsed    | 64        |
# |    total_timesteps | 7894      |
# | train/             |           |
# |    actor_loss      | 1.52e+10  |
# |    critic_loss     | 3.9e+21   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 7793      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 547       |
# |    ep_rew_mean     | -7.89e+11 |
# | time/              |           |
# |    episodes        | 19        |
# |    fps             | 120       |
# |    time_elapsed    | 85        |
# |    total_timesteps | 10393     |
# | train/             |           |
# |    actor_loss      | 2.29e+10  |
# |    critic_loss     | 3.9e+21   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 10292     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 645      |
# |    ep_rew_mean     | -7.5e+11 |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 120      |
# |    time_elapsed    | 106      |
# |    total_timesteps | 12892    |
# | train/             |          |
# |    actor_loss      | 2.93e+10 |
# |    critic_loss     | 2.91e+18 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12791    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 733       |
# |    ep_rew_mean     | -7.14e+11 |
# | time/              |           |
# |    episodes        | 21        |
# |    fps             | 120       |
# |    time_elapsed    | 128       |
# |    total_timesteps | 15391     |
# | train/             |           |
# |    actor_loss      | 3.37e+10  |
# |    critic_loss     | 3.24e+18  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 15290     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 813       |
# |    ep_rew_mean     | -6.82e+11 |
# | time/              |           |
# |    episodes        | 22        |
# |    fps             | 120       |
# |    time_elapsed    | 148       |
# |    total_timesteps | 17890     |
# | train/             |           |
# |    actor_loss      | 3.77e+10  |
# |    critic_loss     | 4.05e+18  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 17789     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 886       |
# |    ep_rew_mean     | -6.52e+11 |
# | time/              |           |
# |    episodes        | 23        |
# |    fps             | 120       |
# |    time_elapsed    | 169       |
# |    total_timesteps | 20389     |
# | train/             |           |
# |    actor_loss      | 4.01e+10  |
# |    critic_loss     | 4.2e+18   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 20288     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 954       |
# |    ep_rew_mean     | -6.25e+11 |
# | time/              |           |
# |    episodes        | 24        |
# |    fps             | 120       |
# |    time_elapsed    | 190       |
# |    total_timesteps | 22888     |
# | train/             |           |
# |    actor_loss      | 4.22e+10  |
# |    critic_loss     | 3.9e+21   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 22787     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.02e+03 |
# |    ep_rew_mean     | -6e+11   |
# | time/              |          |
# |    episodes        | 25       |
# |    fps             | 120      |
# |    time_elapsed    | 210      |
# |    total_timesteps | 25387    |
# | train/             |          |
# |    actor_loss      | 4.34e+10 |
# |    critic_loss     | 5.28e+18 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 25286    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.07e+03  |
# |    ep_rew_mean     | -5.77e+11 |
# | time/              |           |
# |    episodes        | 26        |
# |    fps             | 121       |
# |    time_elapsed    | 229       |
# |    total_timesteps | 27886     |
# | train/             |           |
# |    actor_loss      | 4.41e+10  |
# |    critic_loss     | 6.17e+18  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 27785     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.13e+03  |
# |    ep_rew_mean     | -5.56e+11 |
# | time/              |           |
# |    episodes        | 27        |
# |    fps             | 121       |
# |    time_elapsed    | 250       |
# |    total_timesteps | 30385     |
# | train/             |           |
# |    actor_loss      | 4.38e+10  |
# |    critic_loss     | 4.59e+18  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 30284     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.17e+03  |
# |    ep_rew_mean     | -5.36e+11 |
# | time/              |           |
# |    episodes        | 28        |
# |    fps             | 121       |
# |    time_elapsed    | 271       |
# |    total_timesteps | 32884     |
# | train/             |           |
# |    actor_loss      | 4.32e+10  |
# |    critic_loss     | 5.3e+18   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 32783     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.22e+03  |
# |    ep_rew_mean     | -5.17e+11 |
# | time/              |           |
# |    episodes        | 29        |
# |    fps             | 121       |
# |    time_elapsed    | 291       |
# |    total_timesteps | 35383     |
# | train/             |           |
# |    actor_loss      | 4.22e+10  |
# |    critic_loss     | 4.91e+18  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 35282     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.26e+03 |
# |    ep_rew_mean     | -5e+11   |
# | time/              |          |
# |    episodes        | 30       |
# |    fps             | 121      |
# |    time_elapsed    | 311      |
# |    total_timesteps | 37882    |
# | train/             |          |
# |    actor_loss      | 4.12e+10 |
# |    critic_loss     | 3.94e+18 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 37781    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.3e+03   |
# |    ep_rew_mean     | -4.84e+11 |
# | time/              |           |
# |    episodes        | 31        |
# |    fps             | 120       |
# |    time_elapsed    | 333       |
# |    total_timesteps | 40381     |
# | train/             |           |
# |    actor_loss      | 3.98e+10  |
# |    critic_loss     | 7.82e+21  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 40280     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.34e+03  |
# |    ep_rew_mean     | -4.69e+11 |
# | time/              |           |
# |    episodes        | 32        |
# |    fps             | 120       |
# |    time_elapsed    | 355       |
# |    total_timesteps | 42880     |
# | train/             |           |
# |    actor_loss      | 3.89e+10  |
# |    critic_loss     | 3.84e+18  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 42779     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.38e+03  |
# |    ep_rew_mean     | -4.55e+11 |
# | time/              |           |
# |    episodes        | 33        |
# |    fps             | 120       |
# |    time_elapsed    | 376       |
# |    total_timesteps | 45379     |
# | train/             |           |
# |    actor_loss      | 3.76e+10  |
# |    critic_loss     | 3.9e+21   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 45278     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.41e+03  |
# |    ep_rew_mean     | -4.41e+11 |
# | time/              |           |
# |    episodes        | 34        |
# |    fps             | 120       |
# |    time_elapsed    | 397       |
# |    total_timesteps | 47878     |
# | train/             |           |
# |    actor_loss      | 3.66e+10  |
# |    critic_loss     | 3.26e+18  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 47777     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.44e+03  |
# |    ep_rew_mean     | -4.29e+11 |
# | time/              |           |
# |    episodes        | 35        |
# |    fps             | 120       |
# |    time_elapsed    | 417       |
# |    total_timesteps | 50377     |
# | train/             |           |
# |    actor_loss      | 3.58e+10  |
# |    critic_loss     | 2.92e+18  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 50276     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.47e+03  |
# |    ep_rew_mean     | -4.17e+11 |
# | time/              |           |
# |    episodes        | 36        |
# |    fps             | 120       |
# |    time_elapsed    | 437       |
# |    total_timesteps | 52876     |
# | train/             |           |
# |    actor_loss      | 3.42e+10  |
# |    critic_loss     | 2.81e+18  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 52775     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.5e+03   |
# |    ep_rew_mean     | -4.05e+11 |
# | time/              |           |
# |    episodes        | 37        |
# |    fps             | 121       |
# |    time_elapsed    | 457       |
# |    total_timesteps | 55375     |
# | train/             |           |
# |    actor_loss      | 3.31e+10  |
# |    critic_loss     | 2.9e+18   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 55274     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.52e+03  |
# |    ep_rew_mean     | -3.95e+11 |
# | time/              |           |
# |    episodes        | 38        |
# |    fps             | 121       |
# |    time_elapsed    | 477       |
# |    total_timesteps | 57874     |
# | train/             |           |
# |    actor_loss      | 3.2e+10   |
# |    critic_loss     | 6.04e+18  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 57773     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.55e+03  |
# |    ep_rew_mean     | -3.85e+11 |
# | time/              |           |
# |    episodes        | 39        |
# |    fps             | 121       |
# |    time_elapsed    | 498       |
# |    total_timesteps | 60373     |
# | train/             |           |
# |    actor_loss      | 3.11e+10  |
# |    critic_loss     | 2.25e+18  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 60272     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.57e+03  |
# |    ep_rew_mean     | -3.75e+11 |
# | time/              |           |
# |    episodes        | 40        |
# |    fps             | 121       |
# |    time_elapsed    | 519       |
# |    total_timesteps | 62872     |
# | train/             |           |
# |    actor_loss      | 3.02e+10  |
# |    critic_loss     | 2.5e+18   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 62771     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.59e+03  |
# |    ep_rew_mean     | -3.66e+11 |
# | time/              |           |
# |    episodes        | 41        |
# |    fps             | 121       |
# |    time_elapsed    | 538       |
# |    total_timesteps | 65371     |
# | train/             |           |
# |    actor_loss      | 2.87e+10  |
# |    critic_loss     | 3.89e+21  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 65270     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.62e+03  |
# |    ep_rew_mean     | -3.57e+11 |
# | time/              |           |
# |    episodes        | 42        |
# |    fps             | 121       |
# |    time_elapsed    | 559       |
# |    total_timesteps | 67870     |
# | train/             |           |
# |    actor_loss      | 2.79e+10  |
# |    critic_loss     | 5.08e+18  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 67769     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.64e+03  |
# |    ep_rew_mean     | -3.49e+11 |
# | time/              |           |
# |    episodes        | 43        |
# |    fps             | 121       |
# |    time_elapsed    | 579       |
# |    total_timesteps | 70369     |
# | train/             |           |
# |    actor_loss      | 2.67e+10  |
# |    critic_loss     | 1.37e+18  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 70268     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.66e+03  |
# |    ep_rew_mean     | -3.41e+11 |
# | time/              |           |
# |    episodes        | 44        |
# |    fps             | 121       |
# |    time_elapsed    | 599       |
# |    total_timesteps | 72868     |
# | train/             |           |
# |    actor_loss      | 2.58e+10  |
# |    critic_loss     | 1.45e+18  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 72767     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.67e+03  |
# |    ep_rew_mean     | -3.33e+11 |
# | time/              |           |
# |    episodes        | 45        |
# |    fps             | 121       |
# |    time_elapsed    | 620       |
# |    total_timesteps | 75367     |
# | train/             |           |
# |    actor_loss      | 2.49e+10  |
# |    critic_loss     | 1.28e+18  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 75266     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.69e+03  |
# |    ep_rew_mean     | -3.26e+11 |
# | time/              |           |
# |    episodes        | 46        |
# |    fps             | 121       |
# |    time_elapsed    | 640       |
# |    total_timesteps | 77866     |
# | train/             |           |
# |    actor_loss      | 2.42e+10  |
# |    critic_loss     | 1.24e+18  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 77765     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.71e+03  |
# |    ep_rew_mean     | -3.19e+11 |
# | time/              |           |
# |    episodes        | 47        |
# |    fps             | 121       |
# |    time_elapsed    | 660       |
# |    total_timesteps | 80365     |
# | train/             |           |
# |    actor_loss      | 2.34e+10  |
# |    critic_loss     | 1.21e+18  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 80264     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.73e+03  |
# |    ep_rew_mean     | -3.13e+11 |
# | time/              |           |
# |    episodes        | 48        |
# |    fps             | 121       |
# |    time_elapsed    | 680       |
# |    total_timesteps | 82864     |
# | train/             |           |
# |    actor_loss      | 2.25e+10  |
# |    critic_loss     | 9.86e+17  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 82763     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.74e+03  |
# |    ep_rew_mean     | -3.06e+11 |
# | time/              |           |
# |    episodes        | 49        |
# |    fps             | 121       |
# |    time_elapsed    | 700       |
# |    total_timesteps | 85363     |
# | train/             |           |
# |    actor_loss      | 2.18e+10  |
# |    critic_loss     | 9.92e+17  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 85262     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.76e+03 |
# |    ep_rew_mean     | -3e+11   |
# | time/              |          |
# |    episodes        | 50       |
# |    fps             | 121      |
# |    time_elapsed    | 720      |
# |    total_timesteps | 87862    |
# | train/             |          |
# |    actor_loss      | 2.09e+10 |
# |    critic_loss     | 1.01e+18 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 87761    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.77e+03  |
# |    ep_rew_mean     | -2.94e+11 |
# | time/              |           |
# |    episodes        | 51        |
# |    fps             | 121       |
# |    time_elapsed    | 740       |
# |    total_timesteps | 90361     |
# | train/             |           |
# |    actor_loss      | 2.02e+10  |
# |    critic_loss     | 8.42e+17  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 90260     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.79e+03  |
# |    ep_rew_mean     | -2.88e+11 |
# | time/              |           |
# |    episodes        | 52        |
# |    fps             | 122       |
# |    time_elapsed    | 760       |
# |    total_timesteps | 92860     |
# | train/             |           |
# |    actor_loss      | 1.96e+10  |
# |    critic_loss     | 7.24e+17  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 92759     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.8e+03   |
# |    ep_rew_mean     | -2.83e+11 |
# | time/              |           |
# |    episodes        | 53        |
# |    fps             | 122       |
# |    time_elapsed    | 780       |
# |    total_timesteps | 95359     |
# | train/             |           |
# |    actor_loss      | 1.89e+10  |
# |    critic_loss     | 3.9e+21   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 95258     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.81e+03  |
# |    ep_rew_mean     | -2.78e+11 |
# | time/              |           |
# |    episodes        | 54        |
# |    fps             | 122       |
# |    time_elapsed    | 801       |
# |    total_timesteps | 97858     |
# | train/             |           |
# |    actor_loss      | 1.88e+10  |
# |    critic_loss     | 7.49e+17  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 97757     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.82e+03  |
# |    ep_rew_mean     | -2.73e+11 |
# | time/              |           |
# |    episodes        | 55        |
# |    fps             | 122       |
# |    time_elapsed    | 821       |
# |    total_timesteps | 100357    |
# | train/             |           |
# |    actor_loss      | 1.8e+10   |
# |    critic_loss     | 6.11e+17  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 100256    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.84e+03  |
# |    ep_rew_mean     | -2.68e+11 |
# | time/              |           |
# |    episodes        | 56        |
# |    fps             | 122       |
# |    time_elapsed    | 841       |
# |    total_timesteps | 102856    |
# | train/             |           |
# |    actor_loss      | 1.76e+10  |
# |    critic_loss     | 6.18e+17  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 102755    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.85e+03  |
# |    ep_rew_mean     | -2.63e+11 |
# | time/              |           |
# |    episodes        | 57        |
# |    fps             | 122       |
# |    time_elapsed    | 862       |
# |    total_timesteps | 105355    |
# | train/             |           |
# |    actor_loss      | 1.71e+10  |
# |    critic_loss     | 5.83e+17  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 105254    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.86e+03  |
# |    ep_rew_mean     | -2.59e+11 |
# | time/              |           |
# |    episodes        | 58        |
# |    fps             | 122       |
# |    time_elapsed    | 882       |
# |    total_timesteps | 107854    |
# | train/             |           |
# |    actor_loss      | 1.66e+10  |
# |    critic_loss     | 4.69e+17  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 107753    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.87e+03  |
# |    ep_rew_mean     | -2.54e+11 |
# | time/              |           |
# |    episodes        | 59        |
# |    fps             | 122       |
# |    time_elapsed    | 902       |
# |    total_timesteps | 110353    |
# | train/             |           |
# |    actor_loss      | 1.64e+10  |
# |    critic_loss     | 5.39e+17  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 110252    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.88e+03 |
# |    ep_rew_mean     | -2.5e+11 |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 122      |
# |    time_elapsed    | 922      |
# |    total_timesteps | 112852   |
# | train/             |          |
# |    actor_loss      | 1.58e+10 |
# |    critic_loss     | 4.38e+17 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 112751   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.89e+03  |
# |    ep_rew_mean     | -2.46e+11 |
# | time/              |           |
# |    episodes        | 61        |
# |    fps             | 122       |
# |    time_elapsed    | 941       |
# |    total_timesteps | 115351    |
# | train/             |           |
# |    actor_loss      | 1.53e+10  |
# |    critic_loss     | 3.46e+17  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 115250    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.9e+03   |
# |    ep_rew_mean     | -2.42e+11 |
# | time/              |           |
# |    episodes        | 62        |
# |    fps             | 122       |
# |    time_elapsed    | 961       |
# |    total_timesteps | 117850    |
# | train/             |           |
# |    actor_loss      | 1.49e+10  |
# |    critic_loss     | 4.07e+17  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 117749    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.91e+03  |
# |    ep_rew_mean     | -2.38e+11 |
# | time/              |           |
# |    episodes        | 63        |
# |    fps             | 122       |
# |    time_elapsed    | 981       |
# |    total_timesteps | 120349    |
# | train/             |           |
# |    actor_loss      | 1.41e+10  |
# |    critic_loss     | 3.39e+17  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 120248    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.92e+03  |
# |    ep_rew_mean     | -2.34e+11 |
# | time/              |           |
# |    episodes        | 64        |
# |    fps             | 122       |
# |    time_elapsed    | 1001      |
# |    total_timesteps | 122848    |
# | train/             |           |
# |    actor_loss      | 1.37e+10  |
# |    critic_loss     | 3.38e+17  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 122747    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.93e+03  |
# |    ep_rew_mean     | -2.31e+11 |
# | time/              |           |
# |    episodes        | 65        |
# |    fps             | 122       |
# |    time_elapsed    | 1022      |
# |    total_timesteps | 125347    |
# | train/             |           |
# |    actor_loss      | 1.35e+10  |
# |    critic_loss     | 9.94e+17  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 125246    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.94e+03  |
# |    ep_rew_mean     | -2.27e+11 |
# | time/              |           |
# |    episodes        | 66        |
# |    fps             | 122       |
# |    time_elapsed    | 1047      |
# |    total_timesteps | 127846    |
# | train/             |           |
# |    actor_loss      | 1.3e+10   |
# |    critic_loss     | 2.93e+17  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 127745    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.95e+03  |
# |    ep_rew_mean     | -2.24e+11 |
# | time/              |           |
# |    episodes        | 67        |
# |    fps             | 122       |
# |    time_elapsed    | 1065      |
# |    total_timesteps | 130345    |
# | train/             |           |
# |    actor_loss      | 1.25e+10  |
# |    critic_loss     | 2.36e+17  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 130244    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.95e+03  |
# |    ep_rew_mean     | -2.21e+11 |
# | time/              |           |
# |    episodes        | 68        |
# |    fps             | 122       |
# |    time_elapsed    | 1085      |
# |    total_timesteps | 132844    |
# | train/             |           |
# |    actor_loss      | 1.21e+10  |
# |    critic_loss     | 2.46e+17  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 132743    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.96e+03  |
# |    ep_rew_mean     | -2.17e+11 |
# | time/              |           |
# |    episodes        | 69        |
# |    fps             | 122       |
# |    time_elapsed    | 1103      |
# |    total_timesteps | 135343    |
# | train/             |           |
# |    actor_loss      | 1.17e+10  |
# |    critic_loss     | 1.89e+17  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 135242    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.97e+03  |
# |    ep_rew_mean     | -2.14e+11 |
# | time/              |           |
# |    episodes        | 70        |
# |    fps             | 122       |
# |    time_elapsed    | 1120      |
# |    total_timesteps | 137842    |
# | train/             |           |
# |    actor_loss      | 1.13e+10  |
# |    critic_loss     | 2e+17     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 137741    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.98e+03  |
# |    ep_rew_mean     | -2.11e+11 |
# | time/              |           |
# |    episodes        | 71        |
# |    fps             | 123       |
# |    time_elapsed    | 1138      |
# |    total_timesteps | 140341    |
# | train/             |           |
# |    actor_loss      | 1.08e+10  |
# |    critic_loss     | 1.7e+17   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 140240    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.98e+03  |
# |    ep_rew_mean     | -2.08e+11 |
# | time/              |           |
# |    episodes        | 72        |
# |    fps             | 123       |
# |    time_elapsed    | 1155      |
# |    total_timesteps | 142840    |
# | train/             |           |
# |    actor_loss      | 1.06e+10  |
# |    critic_loss     | 1.67e+17  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 142739    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.99e+03  |
# |    ep_rew_mean     | -2.05e+11 |
# | time/              |           |
# |    episodes        | 73        |
# |    fps             | 123       |
# |    time_elapsed    | 1172      |
# |    total_timesteps | 145339    |
# | train/             |           |
# |    actor_loss      | 1.04e+10  |
# |    critic_loss     | 1.39e+17  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 145238    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 2e+03     |
# |    ep_rew_mean     | -2.03e+11 |
# | time/              |           |
# |    episodes        | 74        |
# |    fps             | 124       |
# |    time_elapsed    | 1189      |
# |    total_timesteps | 147838    |
# | train/             |           |
# |    actor_loss      | 9.89e+09  |
# |    critic_loss     | 3.9e+21   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 147737    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2e+03    |
# |    ep_rew_mean     | -2e+11   |
# | time/              |          |
# |    episodes        | 75       |
# |    fps             | 123      |
# |    time_elapsed    | 1213     |
# |    total_timesteps | 150337   |
# | train/             |          |
# |    actor_loss      | 9.8e+09  |
# |    critic_loss     | 1.47e+17 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 150236   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 2.01e+03  |
# |    ep_rew_mean     | -1.97e+11 |
# | time/              |           |
# |    episodes        | 76        |
# |    fps             | 123       |
# |    time_elapsed    | 1236      |
# |    total_timesteps | 152836    |
# | train/             |           |
# |    actor_loss      | 9.52e+09  |
# |    critic_loss     | 3.9e+21   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 152735    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 2.02e+03  |
# |    ep_rew_mean     | -1.95e+11 |
# | time/              |           |
# |    episodes        | 77        |
# |    fps             | 123       |
# |    time_elapsed    | 1257      |
# |    total_timesteps | 155335    |
# | train/             |           |
# |    actor_loss      | 9.39e+09  |
# |    critic_loss     | 1.27e+17  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 155234    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 2.02e+03  |
# |    ep_rew_mean     | -1.92e+11 |
# | time/              |           |
# |    episodes        | 78        |
# |    fps             | 123       |
# |    time_elapsed    | 1279      |
# |    total_timesteps | 157834    |
# | train/             |           |
# |    actor_loss      | 9.15e+09  |
# |    critic_loss     | 1.26e+17  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 157733    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.03e+03 |
# |    ep_rew_mean     | -1.9e+11 |
# | time/              |          |
# |    episodes        | 79       |
# |    fps             | 123      |
# |    time_elapsed    | 1303     |
# |    total_timesteps | 160333   |
# | train/             |          |
# |    actor_loss      | 8.79e+09 |
# |    critic_loss     | 9.93e+16 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 160232   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 2.04e+03  |
# |    ep_rew_mean     | -1.88e+11 |
# | time/              |           |
# |    episodes        | 80        |
# |    fps             | 122       |
# |    time_elapsed    | 1325      |
# |    total_timesteps | 162832    |
# | train/             |           |
# |    actor_loss      | 8.85e+09  |
# |    critic_loss     | 1.07e+17  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 162731    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 2.04e+03  |
# |    ep_rew_mean     | -1.85e+11 |
# | time/              |           |
# |    episodes        | 81        |
# |    fps             | 122       |
# |    time_elapsed    | 1346      |
# |    total_timesteps | 165331    |
# | train/             |           |
# |    actor_loss      | 8.79e+09  |
# |    critic_loss     | 1.13e+17  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 165230    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 2.05e+03  |
# |    ep_rew_mean     | -1.83e+11 |
# | time/              |           |
# |    episodes        | 82        |
# |    fps             | 122       |
# |    time_elapsed    | 1367      |
# |    total_timesteps | 167830    |
# | train/             |           |
# |    actor_loss      | 8.53e+09  |
# |    critic_loss     | 1.05e+17  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 167729    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 2.05e+03  |
# |    ep_rew_mean     | -1.81e+11 |
# | time/              |           |
# |    episodes        | 83        |
# |    fps             | 122       |
# |    time_elapsed    | 1388      |
# |    total_timesteps | 170329    |
# | train/             |           |
# |    actor_loss      | 8.22e+09  |
# |    critic_loss     | 9.62e+16  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 170228    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 2.06e+03  |
# |    ep_rew_mean     | -1.79e+11 |
# | time/              |           |
# |    episodes        | 84        |
# |    fps             | 122       |
# |    time_elapsed    | 1409      |
# |    total_timesteps | 172828    |
# | train/             |           |
# |    actor_loss      | 8.04e+09  |
# |    critic_loss     | 9.38e+16  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 172727    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 2.06e+03  |
# |    ep_rew_mean     | -1.76e+11 |
# | time/              |           |
# |    episodes        | 85        |
# |    fps             | 122       |
# |    time_elapsed    | 1430      |
# |    total_timesteps | 175327    |
# | train/             |           |
# |    actor_loss      | 7.9e+09   |
# |    critic_loss     | 9.02e+16  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 175226    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 2.07e+03  |
# |    ep_rew_mean     | -1.74e+11 |
# | time/              |           |
# |    episodes        | 86        |
# |    fps             | 122       |
# |    time_elapsed    | 1451      |
# |    total_timesteps | 177826    |
# | train/             |           |
# |    actor_loss      | 7.73e+09  |
# |    critic_loss     | 8.03e+16  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 177725    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 2.07e+03  |
# |    ep_rew_mean     | -1.72e+11 |
# | time/              |           |
# |    episodes        | 87        |
# |    fps             | 122       |
# |    time_elapsed    | 1474      |
# |    total_timesteps | 180325    |
# | train/             |           |
# |    actor_loss      | 7.69e+09  |
# |    critic_loss     | 7.67e+16  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 180224    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.08e+03 |
# |    ep_rew_mean     | -1.7e+11 |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 122      |
# |    time_elapsed    | 1492     |
# |    total_timesteps | 182824   |
# | train/             |          |
# |    actor_loss      | 7.57e+09 |
# |    critic_loss     | 2.82e+17 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 182723   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 2.08e+03  |
# |    ep_rew_mean     | -1.69e+11 |
# | time/              |           |
# |    episodes        | 89        |
# |    fps             | 122       |
# |    time_elapsed    | 1511      |
# |    total_timesteps | 185323    |
# | train/             |           |
# |    actor_loss      | 7.35e+09  |
# |    critic_loss     | 6.36e+16  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 185222    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 2.09e+03  |
# |    ep_rew_mean     | -1.67e+11 |
# | time/              |           |
# |    episodes        | 90        |
# |    fps             | 122       |
# |    time_elapsed    | 1530      |
# |    total_timesteps | 187822    |
# | train/             |           |
# |    actor_loss      | 7.1e+09   |
# |    critic_loss     | 5.64e+16  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 187721    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 2.09e+03  |
# |    ep_rew_mean     | -1.65e+11 |
# | time/              |           |
# |    episodes        | 91        |
# |    fps             | 122       |
# |    time_elapsed    | 1548      |
# |    total_timesteps | 190321    |
# | train/             |           |
# |    actor_loss      | 7.02e+09  |
# |    critic_loss     | 6.01e+16  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 190220    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 2.1e+03   |
# |    ep_rew_mean     | -1.63e+11 |
# | time/              |           |
# |    episodes        | 92        |
# |    fps             | 122       |
# |    time_elapsed    | 1568      |
# |    total_timesteps | 192820    |
# | train/             |           |
# |    actor_loss      | 6.8e+09   |
# |    critic_loss     | 5.36e+16  |
# ...
# |    n_updates       | 312671   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.5e+03  |
# |    ep_rew_mean     | -3.8e+06 |
# | time/              |          |
# |    episodes        | 141      |
# |    fps             | 120      |
# |    time_elapsed    | 2617     |
# |    total_timesteps | 315271   |
# | train/             |          |
# |    actor_loss      | 1.62e+09 |
# |    critic_loss     | 2.56e+15 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 315170   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.5e+03  |
# |    ep_rew_mean     | -3.8e+06 |
# | time/              |          |
# |    episodes        | 142      |
# |    fps             | 120      |
# |    time_elapsed    | 2636     |
# |    total_timesteps | 317770   |
# | train/             |          |
# |    actor_loss      | 1.59e+09 |
# |    critic_loss     | 9.29e+15 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 317669   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.5e+03  |
# |    ep_rew_mean     | -3.8e+06 |
# | time/              |          |
# |    episodes        | 143      |
# |    fps             | 120      |
# |    time_elapsed    | 2656     |
# |    total_timesteps | 320269   |
# | train/             |          |
# |    actor_loss      | 1.48e+09 |
# |    critic_loss     | 2.72e+16 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 320168   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.5e+03  |
# |    ep_rew_mean     | -3.8e+06 |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 120      |
# |    time_elapsed    | 2675     |
# |    total_timesteps | 322768   |
# | train/             |          |
# |    actor_loss      | 1.39e+09 |
# |    critic_loss     | 1.28e+16 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 322667   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.5e+03  |
# |    ep_rew_mean     | -3.8e+06 |
# | time/              |          |
# |    episodes        | 145      |
# |    fps             | 120      |
# |    time_elapsed    | 2694     |
# |    total_timesteps | 325267   |
# | train/             |          |
# |    actor_loss      | 1.22e+09 |
# |    critic_loss     | 3.13e+16 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 325166   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.5e+03  |
# |    ep_rew_mean     | -3.8e+06 |
# | time/              |          |
# |    episodes        | 146      |
# |    fps             | 120      |
# |    time_elapsed    | 2713     |
# |    total_timesteps | 327766   |
# | train/             |          |
# |    actor_loss      | 1.16e+09 |
# |    critic_loss     | 5.02e+15 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 327665   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.5e+03  |
# |    ep_rew_mean     | -3.8e+06 |
# | time/              |          |
# |    episodes        | 147      |
# |    fps             | 120      |
# |    time_elapsed    | 2732     |
# |    total_timesteps | 330265   |
# | train/             |          |
# |    actor_loss      | 1e+09    |
# |    critic_loss     | 7.04e+15 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 330164   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.5e+03  |
# |    ep_rew_mean     | -3.8e+06 |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 120      |
# |    time_elapsed    | 2751     |
# |    total_timesteps | 332764   |
# | train/             |          |
# |    actor_loss      | 7.99e+08 |
# |    critic_loss     | 6.98e+15 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 332663   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.5e+03  |
# |    ep_rew_mean     | -3.8e+06 |
# | time/              |          |
# |    episodes        | 149      |
# |    fps             | 121      |
# |    time_elapsed    | 2770     |
# |    total_timesteps | 335263   |
# | train/             |          |
# |    actor_loss      | 6.26e+08 |
# |    critic_loss     | 3.25e+15 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 335162   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.5e+03  |
# |    ep_rew_mean     | -3.8e+06 |
# | time/              |          |
# |    episodes        | 150      |
# |    fps             | 121      |
# |    time_elapsed    | 2789     |
# |    total_timesteps | 337762   |
# | train/             |          |
# |    actor_loss      | 4.64e+08 |
# |    critic_loss     | 5.49e+15 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 337661   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.5e+03  |
# |    ep_rew_mean     | -3.8e+06 |
# | time/              |          |
# |    episodes        | 151      |
# |    fps             | 121      |
# |    time_elapsed    | 2808     |
# |    total_timesteps | 340261   |
# | train/             |          |
# |    actor_loss      | 2.11e+08 |
# |    critic_loss     | 3.68e+15 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 340160   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.5e+03  |
# |    ep_rew_mean     | -3.8e+06 |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 121      |
# |    time_elapsed    | 2828     |
# |    total_timesteps | 342760   |
# | train/             |          |
# |    actor_loss      | 1.38e+08 |
# |    critic_loss     | 6.51e+15 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 342659   |
# ---------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 25
#      20 model = DDPG('MultiInputPolicy', train_env, buffer_size=10**7, verbose=1, policy_kwargs={
#      21   'features_extractor_class': Custom_EIEE_CNN_Extractor,
#      22   # 'net_arch': [50, 50],
#      23 }, action_noise=NormalActionNoise(mean=0, sigma=0.10*np.ones(5)))
#      24 # }, action_noise=NormalActionNoise(mean=np.zeros((85,)), sigma=0.1),)
# ---> 25 model.learn(total_timesteps=10**10, log_interval=1)
#      26 # model.save("cnn_portoflio_policy")
#
# File c:\Users\sumit\GitRepos\portfolio-rl\venv\Lib\site-packages\stable_baselines3\ddpg\ddpg.py:123, in DDPG.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     114 def learn(
#     115     self: SelfDDPG,
#     116     total_timesteps: int,
#    (...)
#     121     progress_bar: bool = False,
#     122 ) -> SelfDDPG:
# --> 123     return super().learn(
#     124         total_timesteps=total_timesteps,
#     125         callback=callback,
#     126         log_interval=log_interval,
#     127         tb_log_name=tb_log_name,
#     128         reset_num_timesteps=reset_num_timesteps,
#     129         progress_bar=progress_bar,
#     130     )
#
# File c:\Users\sumit\GitRepos\portfolio-rl\venv\Lib\site-packages\stable_baselines3\td3\td3.py:222, in TD3.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     213 def learn(
#     214     self: SelfTD3,
#     215     total_timesteps: int,
#    (...)
#     220     progress_bar: bool = False,
#     221 ) -> SelfTD3:
# --> 222     return super().learn(
#     223         total_timesteps=total_timesteps,
#     224         callback=callback,
#     225         log_interval=log_interval,
#     226         tb_log_name=tb_log_name,
#     227         reset_num_timesteps=reset_num_timesteps,
#     228         progress_bar=progress_bar,
#     229     )
#
# File c:\Users\sumit\GitRepos\portfolio-rl\venv\Lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:328, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     325 assert isinstance(self.train_freq, TrainFreq)  # check done in _setup_learn()
#     327 while self.num_timesteps < total_timesteps:
# --> 328     rollout = self.collect_rollouts(
#     329         self.env,
#     330         train_freq=self.train_freq,
#     331         action_noise=self.action_noise,
#     332         callback=callback,
#     333         learning_starts=self.learning_starts,
#     334         replay_buffer=self.replay_buffer,
#     335         log_interval=log_interval,
#     336     )
#     338     if not rollout.continue_training:
#     339         break
#
# File c:\Users\sumit\GitRepos\portfolio-rl\venv\Lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:558, in OffPolicyAlgorithm.collect_rollouts(self, env, callback, train_freq, replay_buffer, action_noise, learning_starts, log_interval)
#     555     self.actor.reset_noise(env.num_envs)
#     557 # Select action randomly or according to policy
# --> 558 actions, buffer_actions = self._sample_action(learning_starts, action_noise, env.num_envs)
#     560 # Rescale and perform action
#     561 # print(f"at the time action mean={actions.mean()}, median={np.median(actions)}, std={actions.std()=}")
#     562 new_obs, rewards, dones, infos = env.step(actions)
#
# File c:\Users\sumit\GitRepos\portfolio-rl\venv\Lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:390, in OffPolicyAlgorithm._sample_action(self, learning_starts, action_noise, n_envs)
#     385 else:
#     386     # Note: when using continuous actions,
#     387     # we assume that the policy uses tanh to scale the action
#     388     # We use non-deterministic action in the case of SAC, for TD3, it does not matter
#     389     assert self._last_obs is not None, "self._last_obs was not set"
# --> 390     unscaled_action, _ = self.predict(self._last_obs, deterministic=False)
#     391     # print(f"unscaled action min={unscaled_action.min()}, max={unscaled_action.max()}, mean={unscaled_action.mean()}, median={np.median(unscaled_action)}, std={unscaled_action.std()=}")
#     392
#     393 # Rescale the action from [low, high] to [-1, 1]
#     394 if isinstance(self.action_space, spaces.Box):
#
# File c:\Users\sumit\GitRepos\portfolio-rl\venv\Lib\site-packages\stable_baselines3\common\base_class.py:556, in BaseAlgorithm.predict(self, observation, state, episode_start, deterministic)
#     536 def predict(
#     537     self,
#     538     observation: Union[np.ndarray, Dict[str, np.ndarray]],
#    (...)
#     541     deterministic: bool = False,
#     542 ) -> Tuple[np.ndarray, Optional[Tuple[np.ndarray, ...]]]:
#     543     """
#     544     Get the policy action from an observation (and optional hidden state).
#     545     Includes sugar-coating to handle different observations (e.g. normalizing images).
#    (...)
#     554         (used in recurrent policies)
#     555     """
# --> 556     return self.policy.predict(observation, state, episode_start, deterministic)
#
# File c:\Users\sumit\GitRepos\portfolio-rl\venv\Lib\site-packages\stable_baselines3\common\policies.py:368, in BasePolicy.predict(self, observation, state, episode_start, deterministic)
#     365 obs_tensor, vectorized_env = self.obs_to_tensor(observation)
#     367 with th.no_grad():
# --> 368     actions = self._predict(obs_tensor, deterministic=deterministic)
#     369 # Convert to numpy, and reshape to the original action shape
#     370 actions = actions.cpu().numpy().reshape((-1, *self.action_space.shape))  # type: ignore[misc]
#
# File c:\Users\sumit\GitRepos\portfolio-rl\venv\Lib\site-packages\stable_baselines3\td3\policies.py:243, in TD3Policy._predict(self, observation, deterministic)
#     239 def _predict(self, observation: PyTorchObs, deterministic: bool = False) -> th.Tensor:
#     240     # Note: the deterministic deterministic parameter is ignored in the case of TD3.
#     241     #   Predictions are always deterministic.
#     242     # print(f"in here")
# --> 243     return self.actor(observation)
#
# File c:\Users\sumit\GitRepos\portfolio-rl\venv\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\sumit\GitRepos\portfolio-rl\venv\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\sumit\GitRepos\portfolio-rl\venv\Lib\site-packages\stable_baselines3\td3\policies.py:78, in Actor.forward(self, obs)
#      75 def forward(self, obs: th.Tensor) -> th.Tensor:
#      76     # assert deterministic, 'The TD3 actor only outputs deterministic actions'
#      77     features = self.extract_features(obs, self.features_extractor)
# ---> 78     return self.mu(features)
#
# File c:\Users\sumit\GitRepos\portfolio-rl\venv\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\sumit\GitRepos\portfolio-rl\venv\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\sumit\GitRepos\portfolio-rl\venv\Lib\site-packages\torch\nn\modules\container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File c:\Users\sumit\GitRepos\portfolio-rl\venv\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\sumit\GitRepos\portfolio-rl\venv\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\sumit\GitRepos\portfolio-rl\venv\Lib\site-packages\torch\nn\modules\linear.py:116, in Linear.forward(self, input)
#     115 def forward(self, input: Tensor) -> Tensor:
# --> 116     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
env = PortfolioEnvWithTCost(
    # dm=TestDataManager(),
    dm=TrainDataManager(),
    rm=ProfitReward(),
    cp=0.01,#0.10/365,
    cs=0.01,#0.10/365
)
# env = make_vec_env(PortfolioEnvWithTCost, n_envs=1, env_kwargs={
#     'dm': TestDataManager(),
#     'rm': DifferentialSharpeRatioReward(),
#     'cp': 0.10/365,
#     'cs': 0.10/365
# })
obs, _ = env.reset()

port_val = [1.0]
snp_val = [1.0]
actions = []
ys = []
times_arr = [env.dm.times[env.t+15]]
mus = []

for i in range(900):
    action, _ = model.predict(obs, deterministic=True)
    actions.append(action)
    # print(f"external {action=}")
    obs, rewards, terminated, truncated, info = env.step(action)
    ys.append(env.y)
    mus.append(env.mu)
    times_arr.append(env.dm.times[env.t+15])
    port_val.append(info['port_val'])
    # snp_val.append(snp_val[-1] * (1 + env.dm.idx_df[env.dm.idx_df.index == env.dm.times[env.t+15]].vwretd.values[0]))
    if terminated:
        break
# Out:
# self.universe_size=4

# %%
actions[0]
# Out:
# array([-1.,  1., -1., -1., -1.])

# %%
# basic
plt.plot(times_arr, np.array(port_val), label='RL Portfolio')
plt.plot(times_arr, np.array(snp_val), label='S&P')
# plt.yscale('log')
plt.legend()
plt.show()

# %%
plt.plot((actions[0] + 1)/2)
plt.plot(np.linspace(0, 1, 85) / np.linspace(0, 1, 85).sum())
plt.show()
